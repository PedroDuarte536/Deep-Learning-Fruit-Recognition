# %% [markdown]
# # Fruit Classification | Varieties And Oversampling
#
# This project uses a [Kaggle dataset](https://www.kaggle.com/datasets/moltean/fruits) with fruit images in order to create a model that is able to recognise them.
#
# This dataset includes photos of many different fruits and a bunch of different varieties of each. Therefore, we were forced to reduce the amount of samples, choosing to keep three pairs of similar fruits - Apples and Tomatoes, Kiwis and Cocos and Lemons and Oranges - and all the different varieties of each.
#
# More than comparing results of different learning algorithms, our goal will also be to test different manipulations on the dataset - ignoring fruit varieties or not, undersampling and oversampling, and others that we may find insightful.

# %% [markdown]
# ## Dataset Description

# %%
import os
import random
import matplotlib.pyplot as plt

# %%
BASE_DATASET_PATH = './dataset'
TRAIN_DATASET_PATH = BASE_DATASET_PATH + '/Training'
TEST_DATASET_PATH = BASE_DATASET_PATH + '/Test'

# %%
def load_images(path: str, category_transformation) -> dict:
    images = {}
    
    for folder in os.listdir(path):
        category = category_transformation(folder)
        folder = path + '/' + folder
        if category not in images.keys(): images[category] = []
        images[category].append([folder + '/' + file for file in os.listdir(folder)])
        
    return images

def load_dataset_images(category_transformation = lambda category: category):
    train = load_images(TRAIN_DATASET_PATH, category_transformation)
    test = load_images(TEST_DATASET_PATH, category_transformation)
    return list(train.keys()), train, test

def load_dataset_images_debug(categories, train_images, test_images):
    train_samples = { category: sum([len(ims) for ims in images]) for category, images in train_images.items() }
    test_samples = { category: sum([len(ims) for ims in images]) for category, images in test_images.items() }

    print('Train Dataset', train_samples, sep='\n', end='\n\n')
    print('Test Dataset', test_samples, sep='\n')

    fig, (ax_train, ax_test) = plt.subplots(1, 2, figsize=(15, 5))

    ax_train.bar(categories, [ sum([len(ims) for ims in images]) for category, images in train_images.items() ])
    ax_train.set_title('Train Dataset')
    ax_train.set_xlabel('Fuits')
    ax_train.set_ylabel('Samples #')

    ax_test.bar(categories, [ sum([len(ims) for ims in images]) for category, images in test_images.items() ])
    ax_test.set_title('Test Dataset')
    ax_test.set_xlabel('Fuits')
    ax_test.set_ylabel('Samples #')

    plt.show()

# %%
categories, train_images, test_images = load_dataset_images()

# Debugging information
load_dataset_images_debug(categories, train_images, test_images)
# Out:
# Train Dataset
# {'Apple Golden 1': 480, 'Apple Granny Smith': 492, 'Apple Red 3': 429, 'Tomato Maroon': 367, 'Apple Golden 3': 481, 'Orange': 479, 'Tomato 2': 672, 'Cocos': 490, 'Apple Red 2': 492, 'Tomato not Ripened': 474, 'Tomato Yellow': 459, 'Kiwi': 466, 'Apple Braeburn': 492, 'Tomato Heart': 684, 'Tomato 4': 479, 'Tomato 1': 738, 'Apple Golden 2': 492, 'Apple Red Delicious': 490, 'Apple Red Yellow 1': 492, 'Tomato 3': 738, 'Tomato Cherry Red': 492, 'Lemon': 492, 'Apple Crimson Snow': 444, 'Lemon Meyer': 490, 'Apple Pink Lady': 456, 'Apple Red Yellow 2': 672, 'Apple Red 1': 492}
#
# Test Dataset
# {'Apple Golden 1': 160, 'Apple Granny Smith': 164, 'Apple Red 3': 144, 'Tomato Maroon': 127, 'Apple Golden 3': 161, 'Orange': 160, 'Tomato 2': 225, 'Cocos': 166, 'Apple Red 2': 164, 'Tomato not Ripened': 158, 'Tomato Yellow': 153, 'Kiwi': 156, 'Apple Braeburn': 164, 'Tomato Heart': 228, 'Tomato 4': 160, 'Tomato 1': 246, 'Apple Golden 2': 164, 'Apple Red Delicious': 166, 'Apple Red Yellow 1': 164, 'Tomato 3': 246, 'Tomato Cherry Red': 164, 'Lemon': 164, 'Apple Crimson Snow': 148, 'Lemon Meyer': 166, 'Apple Pink Lady': 152, 'Apple Red Yellow 2': 219, 'Apple Red 1': 164}

# %% [markdown]
# ## Balance Dataset

# %%
# Balance training dataset
max_number_collections = max([ len(collections) for collections in train_images.values() ])
min_number_samples = 150
train_images_balanced = { category: [ image for collection in collections for image in random.sample(collection, min([int(min_number_samples/len(collections)), len(collection)])) ] for category, collections in train_images.items() }
train_images_balanced = { category: images + random.sample([image for collection in train_images[category] for image in collection if image not in train_images_balanced[category]], min([min_number_samples - len(train_images_balanced[category]), len([image for collection in train_images[category] for image in collection]) - len(train_images_balanced[category])])) for category, images in train_images_balanced.items() }

# %%
# Format datasets
train_dataset = train_images_balanced
test_dataset = { category: [ image for collection in collections for image in collection ] for category, collections in test_images.items() }

for category, images in train_dataset.items():
    while len(images) < min_number_samples:
        train_dataset[category].extend([image for collection in train_images[category] for image in collection][:min_number_samples-len(images)])
        
for category, images in test_dataset.items():
    while len(images) < int(min_number_samples*.3):
        test_dataset[category].extend([image for collection in test_images[category] for image in collection][:int(min_number_samples*.3)-len(images)])

# Debugging information
load_dataset_images_debug(categories, { category: [images] for category, images in train_dataset.items() }, { category: [images] for category, images in test_dataset.items() })
# Out:
# Train Dataset
# {'Apple Golden 1': 150, 'Apple Granny Smith': 150, 'Apple Red 3': 150, 'Tomato Maroon': 150, 'Apple Golden 3': 150, 'Orange': 150, 'Tomato 2': 150, 'Cocos': 150, 'Apple Red 2': 150, 'Tomato not Ripened': 150, 'Tomato Yellow': 150, 'Kiwi': 150, 'Apple Braeburn': 150, 'Tomato Heart': 150, 'Tomato 4': 150, 'Tomato 1': 150, 'Apple Golden 2': 150, 'Apple Red Delicious': 150, 'Apple Red Yellow 1': 150, 'Tomato 3': 150, 'Tomato Cherry Red': 150, 'Lemon': 150, 'Apple Crimson Snow': 150, 'Lemon Meyer': 150, 'Apple Pink Lady': 150, 'Apple Red Yellow 2': 150, 'Apple Red 1': 150}
#
# Test Dataset
# {'Apple Golden 1': 160, 'Apple Granny Smith': 164, 'Apple Red 3': 144, 'Tomato Maroon': 127, 'Apple Golden 3': 161, 'Orange': 160, 'Tomato 2': 225, 'Cocos': 166, 'Apple Red 2': 164, 'Tomato not Ripened': 158, 'Tomato Yellow': 153, 'Kiwi': 156, 'Apple Braeburn': 164, 'Tomato Heart': 228, 'Tomato 4': 160, 'Tomato 1': 246, 'Apple Golden 2': 164, 'Apple Red Delicious': 166, 'Apple Red Yellow 1': 164, 'Tomato 3': 246, 'Tomato Cherry Red': 164, 'Lemon': 164, 'Apple Crimson Snow': 148, 'Lemon Meyer': 166, 'Apple Pink Lady': 152, 'Apple Red Yellow 2': 219, 'Apple Red 1': 164}

# %%
import matplotlib.image as mpimg

# %%
def load_image_files(data):
    return { category: [ mpimg.imread(image) for image in images ] for category, images in data.items() }

def load_image_files_debug(categories, data, subtitle=''):
    fig, axs = plt.subplots(1, len(categories), figsize=(18, 3), dpi=180)
    fig.suptitle('Fruits' + (' | ' + subtitle) if subtitle else '')

    for idx in range(len(categories)):
        category = categories[idx]
        print('Shape of first "{}" image -'.format(category), data[category][0].shape)
        axs[idx].imshow(data[category][0])
        axs[idx].set_title(category)

# %%
train_dataset_images = load_image_files(train_dataset)
test_dataset_images = load_image_files(test_dataset)

# Debug Training Dataset Information
load_image_files_debug(categories, train_dataset_images, 'Trainning Data')
load_image_files_debug(categories, test_dataset_images, 'Testing Data')
# Out:
# Shape of first "Apple Golden 1" image - (100, 100, 3)
# Shape of first "Apple Granny Smith" image - (100, 100, 3)
# Shape of first "Apple Red 3" image - (100, 100, 3)
# Shape of first "Tomato Maroon" image - (100, 100, 3)
# Shape of first "Apple Golden 3" image - (100, 100, 3)
# Shape of first "Orange" image - (100, 100, 3)
# Shape of first "Tomato 2" image - (100, 100, 3)
# Shape of first "Cocos" image - (100, 100, 3)
# Shape of first "Apple Red 2" image - (100, 100, 3)
# Shape of first "Tomato not Ripened" image - (100, 100, 3)
# Shape of first "Tomato Yellow" image - (100, 100, 3)
# Shape of first "Kiwi" image - (100, 100, 3)
# Shape of first "Apple Braeburn" image - (100, 100, 3)
# Shape of first "Tomato Heart" image - (100, 100, 3)
# Shape of first "Tomato 4" image - (100, 100, 3)
# Shape of first "Tomato 1" image - (100, 100, 3)
# Shape of first "Apple Golden 2" image - (100, 100, 3)
# Shape of first "Apple Red Delicious" image - (100, 100, 3)
# Shape of first "Apple Red Yellow 1" image - (100, 100, 3)
# Shape of first "Tomato 3" image - (100, 100, 3)
# Shape of first "Tomato Cherry Red" image - (100, 100, 3)
# Shape of first "Lemon" image - (100, 100, 3)
# Shape of first "Apple Crimson Snow" image - (100, 100, 3)
# Shape of first "Lemon Meyer" image - (100, 100, 3)
# Shape of first "Apple Pink Lady" image - (100, 100, 3)
# Shape of first "Apple Red Yellow 2" image - (100, 100, 3)
# Shape of first "Apple Red 1" image - (100, 100, 3)
# Shape of first "Apple Golden 1" image - (100, 100, 3)
# Shape of first "Apple Granny Smith" image - (100, 100, 3)
# Shape of first "Apple Red 3" image - (100, 100, 3)
# Shape of first "Tomato Maroon" image - (100, 100, 3)
# Shape of first "Apple Golden 3" image - (100, 100, 3)
# Shape of first "Orange" image - (100, 100, 3)
# Shape of first "Tomato 2" image - (100, 100, 3)
# Shape of first "Cocos" image - (100, 100, 3)
# Shape of first "Apple Red 2" image - (100, 100, 3)
# Shape of first "Tomato not Ripened" image - (100, 100, 3)
# Shape of first "Tomato Yellow" image - (100, 100, 3)
# Shape of first "Kiwi" image - (100, 100, 3)
# Shape of first "Apple Braeburn" image - (100, 100, 3)
# Shape of first "Tomato Heart" image - (100, 100, 3)
# Shape of first "Tomato 4" image - (100, 100, 3)
# Shape of first "Tomato 1" image - (100, 100, 3)
# Shape of first "Apple Golden 2" image - (100, 100, 3)
# Shape of first "Apple Red Delicious" image - (100, 100, 3)
# Shape of first "Apple Red Yellow 1" image - (100, 100, 3)
# Shape of first "Tomato 3" image - (100, 100, 3)
# Shape of first "Tomato Cherry Red" image - (100, 100, 3)
# Shape of first "Lemon" image - (100, 100, 3)
# Shape of first "Apple Crimson Snow" image - (100, 100, 3)
# Shape of first "Lemon Meyer" image - (100, 100, 3)
# Shape of first "Apple Pink Lady" image - (100, 100, 3)
# Shape of first "Apple Red Yellow 2" image - (100, 100, 3)
# Shape of first "Apple Red 1" image - (100, 100, 3)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def decomposition(dataset):
    X_dataset = []
    y_dataset = []
    
    for category, images in dataset.items():
        X_dataset.extend(images)
        y_dataset.extend([category for _ in range(len(images))])
    
    scaler = StandardScaler()
    X_dataset = scaler.fit_transform([i.flatten() for i in X_dataset])
    
    return X_dataset, y_dataset

# %%
X_train, y_train = decomposition(train_dataset_images)
X_test, y_test = decomposition(test_dataset_images)

# Debugging info
print("Train data")
print("X length: ", len(X_train))
print("y length: ", len(y_train))

print()

print("Test data")
print("X length: ", len(X_test))
print("y length: ", len(y_test))
# Out:
# Train data
# X length:  4050
# y length:  4050
#
# Test data
# X length:  4653
# y length:  4653

# %% [markdown]
# ## Principal Component Analysis

# %%
pca = PCA(n_components=2)
dataIn2D = pca.fit_transform(X_train)

colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'w']
markers = ['o', 'x', 'v', 'd']
markers = [ [color, marker] for marker in markers for color in colors ]

categories = list(train_dataset_images.keys())

for i in range(len(categories)):
    start = i*len(train_dataset_images[categories[i]])
    end = start+len(train_dataset_images[categories[i]])
    plt.scatter(dataIn2D[start:end,0], dataIn2D[start:end,1], color=markers[i][0], marker=markers[i][1], label=categories[i])

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans

kmeans = KMeans(init="k-means++", n_clusters=len(categories), n_init=4)
kmeans.fit(dataIn2D)

# Step size of the mesh. Decrease to increase the quality of the VQ.
h = 0.02  # point in the mesh [x_min, x_max]x[y_min, y_max].

# Plot the decision boundary. For that, we will assign a color to each
x_min, x_max = dataIn2D[:, 0].min() - 1, dataIn2D[:, 0].max() + 1
y_min, y_max = dataIn2D[:, 1].min() - 1, dataIn2D[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Obtain labels for each point in mesh. Use last trained model.
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(
    Z,
    interpolation="nearest",
    extent=(xx.min(), xx.max(), yy.min(), yy.max()),
    cmap=plt.cm.Paired,
    aspect="auto",
    origin="lower",
)

# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
for i in range(len(categories)):
    start = i*len(train_dataset_images[categories[i]])
    end = start+len(train_dataset_images[categories[i]])
    plt.scatter(dataIn2D[start:end,0], dataIn2D[start:end,1], color=colors[categories[i]], marker=markers[categories[i]], label=categories[i])
    
plt.scatter(
    centroids[:, 0],
    centroids[:, 1],
    color="w", 
    marker="X",
    s=169,
    linewidths=3,
    zorder=10
)
plt.title(
    "K-means clustering on the digits dataset (PCA-reduced data)\n"
    "Centroids are marked with white cross"
)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.legend()
plt.show()

# %%
pca = PCA(n_components=3)
dataIn3D = pca.fit_transform(X_train)

categories = list(train_dataset_images.keys())
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(len(categories)):
    start = i*len(train_dataset_images[categories[i]])
    end = start+len(train_dataset_images[categories[i]])
    ax.scatter(dataIn3D[start:end,0], dataIn3D[start:end,1], dataIn3D[start:end,2], color=markers[i][0], marker=markers[i][1], label=categories[i])

    ax.set_xlabel('PC1')
    ax.set_ylabel('PC2')
    ax.set_zlabel('PC3')
    ax.legend()

# %% [markdown]
# ## Training - SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import plot_confusion_matrix, precision_score, recall_score, f1_score,roc_curve,accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn import preprocessing

# %%
clf = SVC(gamma='auto', kernel='linear', probability=True)
clf.fit(X_train, y_train) 


plot_confusion_matrix(clf, X_test, y_test, normalize='true')  
plt.show()

y_pred = clf.predict(X_test)

#Evaluation
precision = accuracy_score(y_pred, y_test) * 100
print("Accuracy with SVM: {0:.2f}%".format(precision))

# calculate the FPR and TPR for all thresholds of the classification
probs = clf.predict_proba(X_test)
probs = probs[:, 1]

# %%
y_score = clf.fit(X_train, y_train).decision_function(X_test)

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

#labels = preprocessing.label_binarize(y_test, classes=[i for i in range(len(y_test))])
#print(labels)
#svm_fpr, svm_tpr, thresholds = roc_curve([i for i in range(len(y_test))], probs)
#svm_auc = roc_auc_score(y_test, probs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26003/143014182.py in <module>
#       1 y_score = clf.fit(X_train, y_train).decision_function(X_test)
#       2
# ----> 3 fpr, tpr, _ = roc_curve(y_test, y_score)
#       4 roc_auc = auc(fpr, tpr)
#       5
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     911
#     912     """
# --> 913     fps, tps, thresholds = _binary_clf_curve(
#     914         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     915
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     689     if not (y_type == "binary" or
#     690             (y_type == "multiclass" and pos_label is not None)):
# --> 691         raise ValueError("{0} format is not supported".format(y_type))
#     692
#     693     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %% [markdown]
# ### K-Fold

# %%
pred_kfold = cross_val_score(clf, X_train, y_train, cv=5) 
print("Accuracy with SVM and K-FOLD CROSS VALIDATION: %0.2f (+/- %0.2f)" % (pred_kfold.mean(), pred_kfold.std() * 2))
# Out:
# Accuracy with SVM and K-FOLD CROSS VALIDATION: 0.90 (+/- 0.04)

# %% [markdown]
# ## Training - Deep Learning

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.layers import Activation, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.utils import np_utils
# Out:
# 2022-06-26 12:53:44.049615: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-26 12:53:44.049678: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def get_model(
    n_classes,
    conv_layers=4, filters_start=16, filters_iteraction_func=lambda f: f*2, input_shape=(100,100,3), 
    kernel_size=2, activation_func='relu', padding='same', pool_size=2, conv_dropout=.3, result_dropout=.4 
):
    model = Sequential()
    
    conv_args = { 'kernel_size':kernel_size, 'activation':activation_func, 'padding':padding }
    
    filters = filters_start
    for i in range(conv_layers):
        args = { 'filters':filters, **conv_args }
        if i == 0: args = { 'input_shape':input_shape, **args }
            
        model.add(Conv2D(**args))
        model.add(MaxPooling2D(pool_size=pool_size))
            
        filters = filters_iteraction_func(filters)
        
    if conv_dropout is not None: model.add(Dropout(conv_dropout))
    model.add(Flatten())
    if result_dropout is not None: model.add(Dropout(result_dropout))
    model.add(Dense(n_classes,activation='softmax'))
    
    return model

def get_compiled_model(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'], **model_args):
    model = get_model(**model_args)
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics) 
    
    return model

def get_train_function(batch_size = 32, epochs=30, shuffle=True, **model_args):
    model = get_compiled_model(**model_args)
    return model, lambda X_train, y_train, X_test, y_test: model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(X_test, y_test),verbose=2,shuffle=shuffle)

# %%
model, fit = get_train_function(n_classes=6)
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 100, 100, 16)      208
#
#  max_pooling2d_16 (MaxPoolin  (None, 50, 50, 16)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 50, 50, 32)        2080
#
#  max_pooling2d_17 (MaxPoolin  (None, 25, 25, 32)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 64)        8256
#
#  max_pooling2d_18 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 12, 12, 128)       32896
#
#  max_pooling2d_19 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 6, 6, 128)         0
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dropout_11 (Dropout)        (None, 4608)              0
#
#  dense_9 (Dense)             (None, 6)                 27654
#
# =================================================================
# Total params: 71,094
# Trainable params: 71,094
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = fit(train_data, transfomed_label_train, test_data, transfomed_label_test)
# Out:
# Epoch 1/30
# 88/88 - 13s - loss: 3.8488 - accuracy: 0.7185 - val_loss: 0.3688 - val_accuracy: 0.8594 - 13s/epoch - 152ms/step
# Epoch 2/30
# 88/88 - 12s - loss: 0.1864 - accuracy: 0.9396 - val_loss: 0.0417 - val_accuracy: 0.9852 - 12s/epoch - 135ms/step
# Epoch 3/30
# 88/88 - 12s - loss: 0.0997 - accuracy: 0.9742 - val_loss: 0.0186 - val_accuracy: 0.9936 - 12s/epoch - 138ms/step
# Epoch 4/30
# 88/88 - 12s - loss: 0.1031 - accuracy: 0.9757 - val_loss: 0.0141 - val_accuracy: 0.9983 - 12s/epoch - 135ms/step
# Epoch 5/30
# 88/88 - 13s - loss: 0.0505 - accuracy: 0.9857 - val_loss: 0.0069 - val_accuracy: 0.9983 - 13s/epoch - 151ms/step
# Epoch 6/30
# 88/88 - 12s - loss: 0.0701 - accuracy: 0.9861 - val_loss: 0.0041 - val_accuracy: 0.9981 - 12s/epoch - 137ms/step
# Epoch 7/30
# 88/88 - 14s - loss: 0.0427 - accuracy: 0.9903 - val_loss: 0.0019 - val_accuracy: 0.9996 - 14s/epoch - 157ms/step
# Epoch 8/30
# 88/88 - 14s - loss: 0.0560 - accuracy: 0.9875 - val_loss: 0.0020 - val_accuracy: 0.9996 - 14s/epoch - 163ms/step
# Epoch 9/30
# 88/88 - 12s - loss: 0.0233 - accuracy: 0.9950 - val_loss: 0.0599 - val_accuracy: 0.9858 - 12s/epoch - 133ms/step
# Epoch 10/30
# 88/88 - 13s - loss: 0.0204 - accuracy: 0.9946 - val_loss: 0.0076 - val_accuracy: 0.9970 - 13s/epoch - 143ms/step
# Epoch 11/30
# 88/88 - 11s - loss: 0.0883 - accuracy: 0.9889 - val_loss: 0.0087 - val_accuracy: 0.9981 - 11s/epoch - 126ms/step
# Epoch 12/30
# 88/88 - 12s - loss: 0.0614 - accuracy: 0.9896 - val_loss: 0.0704 - val_accuracy: 0.9905 - 12s/epoch - 137ms/step
# Epoch 13/30
# 88/88 - 11s - loss: 0.0250 - accuracy: 0.9957 - val_loss: 5.1717e-04 - val_accuracy: 0.9998 - 11s/epoch - 125ms/step
# Epoch 14/30
# 88/88 - 11s - loss: 0.0308 - accuracy: 0.9950 - val_loss: 0.0305 - val_accuracy: 0.9938 - 11s/epoch - 125ms/step
# Epoch 15/30
# 88/88 - 11s - loss: 0.0898 - accuracy: 0.9893 - val_loss: 0.0103 - val_accuracy: 0.9961 - 11s/epoch - 125ms/step
# Epoch 16/30
# 88/88 - 11s - loss: 0.0318 - accuracy: 0.9946 - val_loss: 0.0128 - val_accuracy: 0.9959 - 11s/epoch - 125ms/step
# Epoch 17/30
# 88/88 - 11s - loss: 0.0168 - accuracy: 0.9968 - val_loss: 0.0163 - val_accuracy: 0.9944 - 11s/epoch - 125ms/step
# Epoch 18/30
# 88/88 - 11s - loss: 0.0333 - accuracy: 0.9964 - val_loss: 0.0073 - val_accuracy: 0.9983 - 11s/epoch - 125ms/step
# Epoch 19/30
# 88/88 - 11s - loss: 0.0254 - accuracy: 0.9968 - val_loss: 7.2519e-04 - val_accuracy: 0.9996 - 11s/epoch - 125ms/step
# Epoch 20/30
# 88/88 - 11s - loss: 0.0117 - accuracy: 0.9986 - val_loss: 4.5007e-04 - val_accuracy: 0.9996 - 11s/epoch - 128ms/step
# Epoch 21/30
# 88/88 - 11s - loss: 0.0232 - accuracy: 0.9968 - val_loss: 0.0219 - val_accuracy: 0.9946 - 11s/epoch - 125ms/step
# Epoch 22/30
# 88/88 - 11s - loss: 0.0301 - accuracy: 0.9950 - val_loss: 0.0240 - val_accuracy: 0.9931 - 11s/epoch - 125ms/step
# Epoch 23/30
# 88/88 - 11s - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.7016 - val_accuracy: 0.9387 - 11s/epoch - 127ms/step
# Epoch 24/30
# 88/88 - 11s - loss: 0.0476 - accuracy: 0.9971 - val_loss: 9.4444e-04 - val_accuracy: 0.9996 - 11s/epoch - 125ms/step
# Epoch 25/30
# 88/88 - 11s - loss: 0.0759 - accuracy: 0.9914 - val_loss: 0.1023 - val_accuracy: 0.9837 - 11s/epoch - 126ms/step
# Epoch 26/30
# 88/88 - 11s - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.0665 - val_accuracy: 0.9905 - 11s/epoch - 125ms/step
# Epoch 27/30
# 88/88 - 11s - loss: 0.0384 - accuracy: 0.9961 - val_loss: 0.0037 - val_accuracy: 0.9996 - 11s/epoch - 125ms/step
# Epoch 28/30
# 88/88 - 11s - loss: 0.0022 - accuracy: 0.9996 - val_loss: 9.0506e-04 - val_accuracy: 0.9996 - 11s/epoch - 125ms/step
# Epoch 29/30
# 88/88 - 11s - loss: 0.0194 - accuracy: 0.9979 - val_loss: 2.0979e-04 - val_accuracy: 1.0000 - 11s/epoch - 125ms/step
# Epoch 30/30
# 88/88 - 11s - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0449 - val_accuracy: 0.9916 - 11s/epoch - 124ms/step

# %%
def calc_param_combinations(params, key_idx=0):
    combinations = []
    
    keys = list(params.keys())
    if key_idx >= len(keys): combinations = [ params ]
    
    elif type(params[keys[key_idx]]) == list: 
        for value in params[keys[key_idx]]:
            new_params = {**params}
            new_params[keys[key_idx]] = value
            combinations.extend(calc_param_combinations(new_params, key_idx+1))
    
    else: 
        combinations.extend(calc_param_combinations(params, key_idx+1))
    
    return combinations

def train_hyper_tuning(X_train, y_train, X_test, y_test, params):
    params_combinations = calc_param_combinations(params)
    results = []
    
    for i in range(len(params_combinations)):
        combination = params_combinations[i]
        
        print("Train {}/{} with params: {}".format(i+1, len(params_combinations), ", ".join([str(key)+'='+str(value) for key, value in combination.items()])))
        
        model, fit_func = get_train_function(**combination)
        result = fit_func(X_train, y_train, X_test, y_test)
        results.append({ 'params': combination, 'model': model, 'result': result })
        
    return results

# %%
params = {'n_classes': 6, 'conv_layers': [2,4], 'filters_start': [16,32], 'kernel_size': [2,3], 'optimizer': ['adam', 'rmsprop'], 'epochs': [10,20,30]}

results = train_hyper_tuning(train_data, transfomed_label_train, test_data, transfomed_label_test, params)
# Out:
# Train 1/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=adam, epochs=10
# Epoch 1/10
# 88/88 - 14s - loss: 30.8302 - accuracy: 0.7536 - val_loss: 1.3535 - val_accuracy: 0.9364 - 14s/epoch - 164ms/step
# Epoch 2/10
# 88/88 - 13s - loss: 0.5320 - accuracy: 0.9585 - val_loss: 0.4483 - val_accuracy: 0.9611 - 13s/epoch - 145ms/step
# Epoch 3/10
# 88/88 - 13s - loss: 0.2122 - accuracy: 0.9782 - val_loss: 0.2835 - val_accuracy: 0.9781 - 13s/epoch - 145ms/step
# Epoch 4/10
# 88/88 - 14s - loss: 0.0790 - accuracy: 0.9896 - val_loss: 0.2604 - val_accuracy: 0.9852 - 14s/epoch - 154ms/step
# Epoch 5/10
# 88/88 - 16s - loss: 0.1161 - accuracy: 0.9889 - val_loss: 0.2585 - val_accuracy: 0.9811 - 16s/epoch - 177ms/step
# Epoch 6/10
# 88/88 - 21s - loss: 0.0304 - accuracy: 0.9957 - val_loss: 0.2281 - val_accuracy: 0.9761 - 21s/epoch - 236ms/step
# Epoch 7/10
# 88/88 - 22s - loss: 0.0666 - accuracy: 0.9946 - val_loss: 0.1880 - val_accuracy: 0.9841 - 22s/epoch - 250ms/step
# Epoch 8/10
# 88/88 - 38s - loss: 0.0330 - accuracy: 0.9968 - val_loss: 0.1887 - val_accuracy: 0.9860 - 38s/epoch - 427ms/step
# Epoch 9/10
# 88/88 - 22s - loss: 0.0182 - accuracy: 0.9979 - val_loss: 0.0687 - val_accuracy: 0.9946 - 22s/epoch - 248ms/step
# Epoch 10/10
# 88/88 - 20s - loss: 0.0256 - accuracy: 0.9971 - val_loss: 0.2144 - val_accuracy: 0.9845 - 20s/epoch - 225ms/step
# Train 2/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=adam, epochs=20
# Epoch 1/20
# 88/88 - 18s - loss: 61.4357 - accuracy: 0.7057 - val_loss: 1.6416 - val_accuracy: 0.9226 - 18s/epoch - 210ms/step
# Epoch 2/20
# 88/88 - 13s - loss: 0.8634 - accuracy: 0.9557 - val_loss: 0.6913 - val_accuracy: 0.9523 - 13s/epoch - 150ms/step
# Epoch 3/20
# 88/88 - 14s - loss: 0.1801 - accuracy: 0.9843 - val_loss: 0.4706 - val_accuracy: 0.9665 - 14s/epoch - 161ms/step
# Epoch 4/20
# 88/88 - 13s - loss: 0.1495 - accuracy: 0.9882 - val_loss: 0.8918 - val_accuracy: 0.9519 - 13s/epoch - 147ms/step
# Epoch 5/20
# 88/88 - 13s - loss: 0.1222 - accuracy: 0.9903 - val_loss: 0.2670 - val_accuracy: 0.9764 - 13s/epoch - 149ms/step
# Epoch 6/20
# 88/88 - 13s - loss: 0.0934 - accuracy: 0.9921 - val_loss: 0.0718 - val_accuracy: 0.9929 - 13s/epoch - 148ms/step
# Epoch 7/20
# 88/88 - 14s - loss: 0.0739 - accuracy: 0.9954 - val_loss: 0.1503 - val_accuracy: 0.9899 - 14s/epoch - 163ms/step
# Epoch 8/20
# 88/88 - 14s - loss: 0.0832 - accuracy: 0.9911 - val_loss: 0.4521 - val_accuracy: 0.9675 - 14s/epoch - 159ms/step
# Epoch 9/20
# 88/88 - 14s - loss: 0.0392 - accuracy: 0.9957 - val_loss: 0.2163 - val_accuracy: 0.9839 - 14s/epoch - 157ms/step
# Epoch 10/20
# 88/88 - 14s - loss: 0.0261 - accuracy: 0.9982 - val_loss: 0.3184 - val_accuracy: 0.9824 - 14s/epoch - 156ms/step
# Epoch 11/20
# 88/88 - 13s - loss: 0.0842 - accuracy: 0.9943 - val_loss: 0.0643 - val_accuracy: 0.9929 - 13s/epoch - 144ms/step
# Epoch 12/20
# 88/88 - 13s - loss: 0.0931 - accuracy: 0.9932 - val_loss: 0.1915 - val_accuracy: 0.9783 - 13s/epoch - 150ms/step
# Epoch 13/20
# 88/88 - 13s - loss: 0.0739 - accuracy: 0.9943 - val_loss: 0.6461 - val_accuracy: 0.9716 - 13s/epoch - 149ms/step
# Epoch 14/20
# 88/88 - 13s - loss: 0.1017 - accuracy: 0.9907 - val_loss: 0.0371 - val_accuracy: 0.9946 - 13s/epoch - 150ms/step
# Epoch 15/20
# 88/88 - 13s - loss: 0.0854 - accuracy: 0.9950 - val_loss: 0.3682 - val_accuracy: 0.9738 - 13s/epoch - 151ms/step
# Epoch 16/20
# 88/88 - 18s - loss: 0.0748 - accuracy: 0.9957 - val_loss: 0.7704 - val_accuracy: 0.9759 - 18s/epoch - 207ms/step
# Epoch 17/20
# 88/88 - 15s - loss: 0.0956 - accuracy: 0.9932 - val_loss: 0.1737 - val_accuracy: 0.9847 - 15s/epoch - 166ms/step
# Epoch 18/20
# 88/88 - 14s - loss: 0.0618 - accuracy: 0.9950 - val_loss: 0.0551 - val_accuracy: 0.9931 - 14s/epoch - 162ms/step
# Epoch 19/20
# 88/88 - 14s - loss: 0.0278 - accuracy: 0.9975 - val_loss: 0.0138 - val_accuracy: 0.9976 - 14s/epoch - 159ms/step
# Epoch 20/20
# 88/88 - 13s - loss: 0.0186 - accuracy: 0.9971 - val_loss: 0.0295 - val_accuracy: 0.9946 - 13s/epoch - 149ms/step
# Train 3/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=adam, epochs=30
# Epoch 1/30
# 88/88 - 14s - loss: 21.1986 - accuracy: 0.7124 - val_loss: 0.5499 - val_accuracy: 0.9031 - 14s/epoch - 155ms/step
# Epoch 2/30
# 88/88 - 13s - loss: 0.3901 - accuracy: 0.9428 - val_loss: 0.0823 - val_accuracy: 0.9751 - 13s/epoch - 152ms/step
# Epoch 3/30
# 88/88 - 14s - loss: 0.1195 - accuracy: 0.9771 - val_loss: 0.0721 - val_accuracy: 0.9759 - 14s/epoch - 159ms/step
# Epoch 4/30
# 88/88 - 13s - loss: 0.1612 - accuracy: 0.9717 - val_loss: 0.0460 - val_accuracy: 0.9847 - 13s/epoch - 145ms/step
# Epoch 5/30
# 88/88 - 13s - loss: 0.0459 - accuracy: 0.9893 - val_loss: 0.0984 - val_accuracy: 0.9742 - 13s/epoch - 143ms/step
# Epoch 6/30
# 88/88 - 13s - loss: 0.0197 - accuracy: 0.9950 - val_loss: 0.0270 - val_accuracy: 0.9910 - 13s/epoch - 145ms/step
# Epoch 7/30
# 88/88 - 13s - loss: 0.0272 - accuracy: 0.9932 - val_loss: 0.0051 - val_accuracy: 0.9976 - 13s/epoch - 146ms/step
# Epoch 8/30
# 88/88 - 13s - loss: 0.0318 - accuracy: 0.9939 - val_loss: 0.0094 - val_accuracy: 0.9951 - 13s/epoch - 150ms/step
# Epoch 9/30
# 88/88 - 14s - loss: 0.0481 - accuracy: 0.9907 - val_loss: 0.3990 - val_accuracy: 0.9317 - 14s/epoch - 154ms/step
# Epoch 10/30
# 88/88 - 13s - loss: 0.0390 - accuracy: 0.9911 - val_loss: 0.0727 - val_accuracy: 0.9865 - 13s/epoch - 146ms/step
# Epoch 11/30
# 88/88 - 14s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0376 - val_accuracy: 0.9940 - 14s/epoch - 155ms/step
# Epoch 12/30
# 88/88 - 13s - loss: 0.0164 - accuracy: 0.9961 - val_loss: 0.0439 - val_accuracy: 0.9888 - 13s/epoch - 145ms/step
# Epoch 13/30
# 88/88 - 13s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0280 - val_accuracy: 0.9931 - 13s/epoch - 145ms/step
# Epoch 14/30
# 88/88 - 16s - loss: 0.0868 - accuracy: 0.9914 - val_loss: 0.0777 - val_accuracy: 0.9826 - 16s/epoch - 181ms/step
# Epoch 15/30
# 88/88 - 17s - loss: 0.0524 - accuracy: 0.9886 - val_loss: 0.1671 - val_accuracy: 0.9710 - 17s/epoch - 189ms/step
# Epoch 16/30
# 88/88 - 16s - loss: 0.0243 - accuracy: 0.9954 - val_loss: 0.0386 - val_accuracy: 0.9901 - 16s/epoch - 187ms/step
# Epoch 17/30
# 88/88 - 13s - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.0227 - val_accuracy: 0.9929 - 13s/epoch - 149ms/step
# Epoch 18/30
# 88/88 - 14s - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0212 - val_accuracy: 0.9936 - 14s/epoch - 157ms/step
# Epoch 19/30
# 88/88 - 15s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0242 - val_accuracy: 0.9933 - 15s/epoch - 167ms/step
# Epoch 20/30
# 88/88 - 12s - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.0395 - val_accuracy: 0.9918 - 12s/epoch - 142ms/step
# Epoch 21/30
# 88/88 - 15s - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0150 - val_accuracy: 0.9968 - 15s/epoch - 166ms/step
# Epoch 22/30
# 88/88 - 13s - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0120 - val_accuracy: 0.9963 - 13s/epoch - 143ms/step
# Epoch 23/30
# 88/88 - 13s - loss: 0.0076 - accuracy: 0.9989 - val_loss: 0.1495 - val_accuracy: 0.9772 - 13s/epoch - 142ms/step
# Epoch 24/30
# 88/88 - 13s - loss: 0.1671 - accuracy: 0.9785 - val_loss: 0.0336 - val_accuracy: 0.9961 - 13s/epoch - 150ms/step
# Epoch 25/30
# 88/88 - 13s - loss: 0.0272 - accuracy: 0.9954 - val_loss: 0.0522 - val_accuracy: 0.9897 - 13s/epoch - 152ms/step
# Epoch 26/30
# 88/88 - 13s - loss: 0.0864 - accuracy: 0.9918 - val_loss: 0.1258 - val_accuracy: 0.9708 - 13s/epoch - 151ms/step
# Epoch 27/30
# 88/88 - 13s - loss: 0.0492 - accuracy: 0.9875 - val_loss: 0.1799 - val_accuracy: 0.9652 - 13s/epoch - 146ms/step
# Epoch 28/30
# 88/88 - 13s - loss: 0.0876 - accuracy: 0.9889 - val_loss: 0.1325 - val_accuracy: 0.9718 - 13s/epoch - 148ms/step
# Epoch 29/30
# 88/88 - 13s - loss: 0.0394 - accuracy: 0.9936 - val_loss: 0.0145 - val_accuracy: 0.9981 - 13s/epoch - 144ms/step
# Epoch 30/30
# 88/88 - 15s - loss: 0.0130 - accuracy: 0.9968 - val_loss: 0.0113 - val_accuracy: 0.9983 - 15s/epoch - 166ms/step
# Train 4/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=rmsprop, epochs=10
# Epoch 1/10
# 88/88 - 15s - loss: 81.2678 - accuracy: 0.6981 - val_loss: 1.3341 - val_accuracy: 0.9078 - 15s/epoch - 167ms/step
# Epoch 2/10
# 88/88 - 13s - loss: 1.1014 - accuracy: 0.9328 - val_loss: 7.2037 - val_accuracy: 0.7326 - 13s/epoch - 145ms/step
# Epoch 3/10
# 88/88 - 13s - loss: 0.4166 - accuracy: 0.9660 - val_loss: 0.2512 - val_accuracy: 0.9665 - 13s/epoch - 151ms/step
# Epoch 4/10
# 88/88 - 13s - loss: 0.2368 - accuracy: 0.9746 - val_loss: 0.2714 - val_accuracy: 0.9703 - 13s/epoch - 146ms/step
# Epoch 5/10
# 88/88 - 13s - loss: 0.1710 - accuracy: 0.9853 - val_loss: 0.1525 - val_accuracy: 0.9822 - 13s/epoch - 146ms/step
# Epoch 6/10
# 88/88 - 12s - loss: 0.1319 - accuracy: 0.9875 - val_loss: 0.4211 - val_accuracy: 0.9622 - 12s/epoch - 141ms/step
# Epoch 7/10
# 88/88 - 14s - loss: 0.1575 - accuracy: 0.9868 - val_loss: 0.9050 - val_accuracy: 0.9278 - 14s/epoch - 155ms/step
# Epoch 8/10
# 88/88 - 14s - loss: 0.1803 - accuracy: 0.9857 - val_loss: 0.2125 - val_accuracy: 0.9714 - 14s/epoch - 162ms/step
# Epoch 9/10
# 88/88 - 14s - loss: 0.0725 - accuracy: 0.9939 - val_loss: 0.2882 - val_accuracy: 0.9738 - 14s/epoch - 162ms/step
# Epoch 10/10
# 88/88 - 13s - loss: 0.2442 - accuracy: 0.9861 - val_loss: 0.1812 - val_accuracy: 0.9815 - 13s/epoch - 147ms/step
# Train 5/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=rmsprop, epochs=20
# Epoch 1/20
# 88/88 - 14s - loss: 58.3044 - accuracy: 0.7214 - val_loss: 2.9443 - val_accuracy: 0.8289 - 14s/epoch - 161ms/step
# Epoch 2/20
# 88/88 - 13s - loss: 0.4505 - accuracy: 0.9503 - val_loss: 1.0217 - val_accuracy: 0.9368 - 13s/epoch - 142ms/step
# Epoch 3/20
# 88/88 - 13s - loss: 0.1842 - accuracy: 0.9796 - val_loss: 1.1340 - val_accuracy: 0.9147 - 13s/epoch - 143ms/step
# Epoch 4/20
# 88/88 - 12s - loss: 0.1298 - accuracy: 0.9807 - val_loss: 0.0347 - val_accuracy: 0.9862 - 12s/epoch - 140ms/step
# Epoch 5/20
# 88/88 - 12s - loss: 0.0605 - accuracy: 0.9925 - val_loss: 0.3446 - val_accuracy: 0.9523 - 12s/epoch - 141ms/step
# Epoch 6/20
# 88/88 - 13s - loss: 0.1284 - accuracy: 0.9857 - val_loss: 0.1919 - val_accuracy: 0.9835 - 13s/epoch - 147ms/step
# Epoch 7/20
# 88/88 - 13s - loss: 0.0353 - accuracy: 0.9950 - val_loss: 0.4167 - val_accuracy: 0.9757 - 13s/epoch - 151ms/step
# Epoch 8/20
# 88/88 - 17s - loss: 0.0308 - accuracy: 0.9968 - val_loss: 0.9916 - val_accuracy: 0.9577 - 17s/epoch - 199ms/step
# Epoch 9/20
# 88/88 - 14s - loss: 0.1106 - accuracy: 0.9907 - val_loss: 0.2667 - val_accuracy: 0.9841 - 14s/epoch - 158ms/step
# Epoch 10/20
# 88/88 - 14s - loss: 0.0367 - accuracy: 0.9954 - val_loss: 0.8314 - val_accuracy: 0.9708 - 14s/epoch - 160ms/step
# Epoch 11/20
# 88/88 - 12s - loss: 0.0722 - accuracy: 0.9932 - val_loss: 1.7374 - val_accuracy: 0.9175 - 12s/epoch - 141ms/step
# Epoch 12/20
# 88/88 - 13s - loss: 0.0907 - accuracy: 0.9943 - val_loss: 0.0268 - val_accuracy: 0.9957 - 13s/epoch - 150ms/step
# Epoch 13/20
# 88/88 - 13s - loss: 3.0140e-05 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9968 - 13s/epoch - 150ms/step
# Epoch 14/20
# 88/88 - 13s - loss: 0.1189 - accuracy: 0.9918 - val_loss: 0.5200 - val_accuracy: 0.9721 - 13s/epoch - 145ms/step
# Epoch 15/20
# 88/88 - 13s - loss: 0.0196 - accuracy: 0.9982 - val_loss: 0.2169 - val_accuracy: 0.9854 - 13s/epoch - 146ms/step
# Epoch 16/20
# 88/88 - 13s - loss: 0.1438 - accuracy: 0.9939 - val_loss: 0.9916 - val_accuracy: 0.9422 - 13s/epoch - 149ms/step
# Epoch 17/20
# 88/88 - 13s - loss: 0.0386 - accuracy: 0.9961 - val_loss: 1.6081 - val_accuracy: 0.9484 - 13s/epoch - 149ms/step
# Epoch 18/20
# 88/88 - 13s - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.4621 - val_accuracy: 0.9783 - 13s/epoch - 142ms/step
# Epoch 19/20
# 88/88 - 13s - loss: 0.0389 - accuracy: 0.9971 - val_loss: 0.2222 - val_accuracy: 0.9903 - 13s/epoch - 145ms/step
# Epoch 20/20
# 88/88 - 13s - loss: 0.0442 - accuracy: 0.9968 - val_loss: 0.0701 - val_accuracy: 0.9936 - 13s/epoch - 146ms/step
# Train 6/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=2, optimizer=rmsprop, epochs=30
# Epoch 1/30
# 88/88 - 16s - loss: 37.9206 - accuracy: 0.7185 - val_loss: 1.7565 - val_accuracy: 0.8448 - 16s/epoch - 186ms/step
# Epoch 2/30
# 88/88 - 13s - loss: 0.7069 - accuracy: 0.9428 - val_loss: 0.6591 - val_accuracy: 0.9153 - 13s/epoch - 149ms/step
# Epoch 3/30
# 88/88 - 13s - loss: 0.2545 - accuracy: 0.9689 - val_loss: 0.1083 - val_accuracy: 0.9785 - 13s/epoch - 144ms/step
# Epoch 4/30
# 88/88 - 13s - loss: 0.2243 - accuracy: 0.9832 - val_loss: 0.5169 - val_accuracy: 0.9428 - 13s/epoch - 143ms/step
# Epoch 5/30
# 88/88 - 14s - loss: 0.1061 - accuracy: 0.9893 - val_loss: 0.6246 - val_accuracy: 0.9559 - 14s/epoch - 161ms/step
# Epoch 6/30
# 88/88 - 13s - loss: 0.0796 - accuracy: 0.9918 - val_loss: 1.2950 - val_accuracy: 0.9007 - 13s/epoch - 147ms/step
# Epoch 7/30
# 88/88 - 14s - loss: 0.1075 - accuracy: 0.9878 - val_loss: 0.1251 - val_accuracy: 0.9869 - 14s/epoch - 157ms/step
# Epoch 8/30
# 88/88 - 13s - loss: 0.0206 - accuracy: 0.9979 - val_loss: 0.6791 - val_accuracy: 0.9345 - 13s/epoch - 145ms/step
# Epoch 9/30
# 88/88 - 13s - loss: 0.0958 - accuracy: 0.9886 - val_loss: 0.1367 - val_accuracy: 0.9871 - 13s/epoch - 152ms/step
# Epoch 10/30
# 88/88 - 13s - loss: 0.1414 - accuracy: 0.9911 - val_loss: 0.2722 - val_accuracy: 0.9789 - 13s/epoch - 143ms/step
# Epoch 11/30
# 88/88 - 13s - loss: 0.0949 - accuracy: 0.9921 - val_loss: 0.3648 - val_accuracy: 0.9772 - 13s/epoch - 143ms/step
# Epoch 12/30
# 88/88 - 13s - loss: 0.0536 - accuracy: 0.9961 - val_loss: 0.3820 - val_accuracy: 0.9751 - 13s/epoch - 148ms/step
# Epoch 13/30
# 88/88 - 13s - loss: 0.0469 - accuracy: 0.9968 - val_loss: 0.4737 - val_accuracy: 0.9725 - 13s/epoch - 148ms/step
# Epoch 14/30
# 88/88 - 13s - loss: 0.0428 - accuracy: 0.9971 - val_loss: 0.2669 - val_accuracy: 0.9686 - 13s/epoch - 143ms/step
# Epoch 15/30
# 88/88 - 13s - loss: 0.0435 - accuracy: 0.9950 - val_loss: 0.1183 - val_accuracy: 0.9890 - 13s/epoch - 148ms/step
# Epoch 16/30
# 88/88 - 13s - loss: 0.1706 - accuracy: 0.9903 - val_loss: 0.1498 - val_accuracy: 0.9897 - 13s/epoch - 150ms/step
# Epoch 17/30
# 88/88 - 13s - loss: 0.0402 - accuracy: 0.9954 - val_loss: 0.0487 - val_accuracy: 0.9953 - 13s/epoch - 145ms/step
# Epoch 18/30
# 88/88 - 13s - loss: 0.0445 - accuracy: 0.9954 - val_loss: 0.0570 - val_accuracy: 0.9910 - 13s/epoch - 148ms/step
# Epoch 19/30
# 88/88 - 13s - loss: 0.0122 - accuracy: 0.9979 - val_loss: 0.4717 - val_accuracy: 0.9562 - 13s/epoch - 150ms/step
# Epoch 20/30
# 88/88 - 14s - loss: 0.0975 - accuracy: 0.9928 - val_loss: 0.0573 - val_accuracy: 0.9951 - 14s/epoch - 161ms/step
# Epoch 21/30
# 88/88 - 13s - loss: 0.0185 - accuracy: 0.9979 - val_loss: 0.1116 - val_accuracy: 0.9916 - 13s/epoch - 148ms/step
# Epoch 22/30
# 88/88 - 13s - loss: 0.0159 - accuracy: 0.9982 - val_loss: 0.3212 - val_accuracy: 0.9817 - 13s/epoch - 149ms/step
# Epoch 23/30
# 88/88 - 13s - loss: 0.0578 - accuracy: 0.9971 - val_loss: 0.1454 - val_accuracy: 0.9895 - 13s/epoch - 145ms/step
# Epoch 24/30
# 88/88 - 13s - loss: 0.0382 - accuracy: 0.9961 - val_loss: 0.0570 - val_accuracy: 0.9974 - 13s/epoch - 144ms/step
# Epoch 25/30
# 88/88 - 12s - loss: 0.0448 - accuracy: 0.9971 - val_loss: 0.4411 - val_accuracy: 0.9734 - 12s/epoch - 142ms/step
# Epoch 26/30
# 88/88 - 12s - loss: 0.0220 - accuracy: 0.9979 - val_loss: 0.2061 - val_accuracy: 0.9845 - 12s/epoch - 141ms/step
# Epoch 27/30
# 88/88 - 12s - loss: 3.5613e-06 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9886 - 12s/epoch - 142ms/step
# Epoch 28/30
# 88/88 - 13s - loss: 0.0553 - accuracy: 0.9971 - val_loss: 0.3026 - val_accuracy: 0.9845 - 13s/epoch - 143ms/step
# Epoch 29/30
# 88/88 - 12s - loss: 0.0507 - accuracy: 0.9968 - val_loss: 0.2572 - val_accuracy: 0.9888 - 12s/epoch - 142ms/step
# Epoch 30/30
# 88/88 - 12s - loss: 0.0329 - accuracy: 0.9979 - val_loss: 0.5270 - val_accuracy: 0.9839 - 12s/epoch - 141ms/step
# Train 7/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=3, optimizer=adam, epochs=10
# Epoch 1/10
# 88/88 - 21s - loss: 14.4881 - accuracy: 0.7657 - val_loss: 0.4225 - val_accuracy: 0.9048 - 21s/epoch - 233ms/step
# Epoch 2/10
# 88/88 - 17s - loss: 0.1715 - accuracy: 0.9539 - val_loss: 0.2342 - val_accuracy: 0.9469 - 17s/epoch - 190ms/step
# Epoch 3/10
# 88/88 - 17s - loss: 0.0682 - accuracy: 0.9771 - val_loss: 0.2511 - val_accuracy: 0.9469 - 17s/epoch - 195ms/step
# Epoch 4/10
# 88/88 - 17s - loss: 0.0430 - accuracy: 0.9875 - val_loss: 0.1320 - val_accuracy: 0.9759 - 17s/epoch - 192ms/step
# Epoch 5/10
# 88/88 - 17s - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.1677 - val_accuracy: 0.9680 - 17s/epoch - 190ms/step
# Epoch 6/10
# 88/88 - 16s - loss: 0.0459 - accuracy: 0.9886 - val_loss: 0.1842 - val_accuracy: 0.9615 - 16s/epoch - 187ms/step
# Epoch 7/10
# 88/88 - 17s - loss: 0.0938 - accuracy: 0.9800 - val_loss: 0.1434 - val_accuracy: 0.9718 - 17s/epoch - 189ms/step
# Epoch 8/10
# 88/88 - 17s - loss: 0.0284 - accuracy: 0.9943 - val_loss: 0.0900 - val_accuracy: 0.9766 - 17s/epoch - 189ms/step
# Epoch 9/10
# 88/88 - 17s - loss: 0.0145 - accuracy: 0.9961 - val_loss: 0.1068 - val_accuracy: 0.9663 - 17s/epoch - 194ms/step
# Epoch 10/10
# 88/88 - 17s - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.0882 - val_accuracy: 0.9721 - 17s/epoch - 189ms/step
# Train 8/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=3, optimizer=adam, epochs=20
# Epoch 1/20
# 88/88 - 18s - loss: 17.6826 - accuracy: 0.7371 - val_loss: 0.1921 - val_accuracy: 0.9463 - 18s/epoch - 206ms/step
# Epoch 2/20
# 88/88 - 17s - loss: 0.0857 - accuracy: 0.9735 - val_loss: 0.0246 - val_accuracy: 0.9897 - 17s/epoch - 189ms/step
# Epoch 3/20
# 88/88 - 17s - loss: 0.0220 - accuracy: 0.9936 - val_loss: 0.0816 - val_accuracy: 0.9753 - 17s/epoch - 191ms/step
# Epoch 4/20
# 88/88 - 17s - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.0059 - val_accuracy: 0.9979 - 17s/epoch - 190ms/step
# Epoch 5/20
# 88/88 - 18s - loss: 0.0508 - accuracy: 0.9875 - val_loss: 0.0896 - val_accuracy: 0.9673 - 18s/epoch - 208ms/step
# Epoch 6/20
# 88/88 - 18s - loss: 0.0163 - accuracy: 0.9946 - val_loss: 0.0705 - val_accuracy: 0.9856 - 18s/epoch - 201ms/step
# Epoch 7/20
# 88/88 - 17s - loss: 0.0136 - accuracy: 0.9986 - val_loss: 0.0043 - val_accuracy: 0.9983 - 17s/epoch - 194ms/step
# Epoch 8/20
# 88/88 - 17s - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0088 - val_accuracy: 0.9966 - 17s/epoch - 198ms/step
# Epoch 9/20
# 88/88 - 17s - loss: 0.0454 - accuracy: 0.9918 - val_loss: 0.0400 - val_accuracy: 0.9839 - 17s/epoch - 198ms/step
# Epoch 10/20
# 88/88 - 17s - loss: 0.0252 - accuracy: 0.9936 - val_loss: 0.0554 - val_accuracy: 0.9884 - 17s/epoch - 193ms/step
# Epoch 11/20
# 88/88 - 17s - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0549 - val_accuracy: 0.9933 - 17s/epoch - 192ms/step
# Epoch 12/20
# 88/88 - 17s - loss: 0.0384 - accuracy: 0.9900 - val_loss: 0.3865 - val_accuracy: 0.9523 - 17s/epoch - 193ms/step
# Epoch 13/20
# 88/88 - 18s - loss: 0.0490 - accuracy: 0.9857 - val_loss: 0.1931 - val_accuracy: 0.9776 - 18s/epoch - 202ms/step
# Epoch 14/20
# 88/88 - 17s - loss: 0.0187 - accuracy: 0.9950 - val_loss: 0.1017 - val_accuracy: 0.9819 - 17s/epoch - 194ms/step
# Epoch 15/20
# 88/88 - 18s - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0777 - val_accuracy: 0.9867 - 18s/epoch - 204ms/step
# Epoch 16/20
# 88/88 - 17s - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.0845 - val_accuracy: 0.9875 - 17s/epoch - 194ms/step
# Epoch 17/20
# 88/88 - 17s - loss: 0.0058 - accuracy: 0.9989 - val_loss: 0.0479 - val_accuracy: 0.9918 - 17s/epoch - 197ms/step
# Epoch 18/20
# 88/88 - 19s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9882 - 19s/epoch - 212ms/step
# Epoch 19/20
# 88/88 - 23s - loss: 9.8196e-04 - accuracy: 0.9996 - val_loss: 0.0303 - val_accuracy: 0.9920 - 23s/epoch - 260ms/step
# Epoch 20/20
# 88/88 - 13s - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0379 - val_accuracy: 0.9933 - 13s/epoch - 152ms/step
# Train 9/48 with params: n_classes=6, conv_layers=2, filters_start=16, kernel_size=3, optimizer=adam, epochs=30
# Epoch 1/30
# 88/88 - 15s - loss: 23.3350 - accuracy: 0.5758 - val_loss: 0.7855 - val_accuracy: 0.7066 - 15s/epoch - 172ms/step
# Epoch 2/30
# 88/88 - 13s - loss: 0.4518 - accuracy: 0.8498 - val_loss: 0.3674 - val_accuracy: 0.8708 - 13s/epoch - 150ms/step
# Epoch 3/30

# %%
import numpy as np

train_data = np.array([img_to_array(load_img(image)) for collection in train_dataset.values() for image in collection])
test_data = np.array([img_to_array(load_img(image)) for collection in test_dataset.values() for image in collection])

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
transfomed_label_train = encoder.fit_transform(y_train)

encoder = LabelBinarizer()
transfomed_label_test = encoder.fit_transform(y_test)

history = model.fit(train_data, transfomed_label_train, batch_size = 32, epochs=30, validation_data=(test_data, transfomed_label_test),
        verbose=2, shuffle=True)
# Out:
# Epoch 1/30
# 88/88 - 13s - loss: 2.5789 - accuracy: 0.7225 - val_loss: 0.4000 - val_accuracy: 0.8349 - 13s/epoch - 153ms/step
# Epoch 2/30
# 88/88 - 12s - loss: 0.2354 - accuracy: 0.9299 - val_loss: 0.3478 - val_accuracy: 0.8749 - 12s/epoch - 132ms/step
# Epoch 3/30
# 88/88 - 11s - loss: 0.1757 - accuracy: 0.9560 - val_loss: 0.0109 - val_accuracy: 0.9966 - 11s/epoch - 129ms/step
# Epoch 4/30
# 88/88 - 11s - loss: 0.0772 - accuracy: 0.9825 - val_loss: 0.0132 - val_accuracy: 0.9951 - 11s/epoch - 129ms/step
# Epoch 5/30
# 88/88 - 11s - loss: 0.1912 - accuracy: 0.9739 - val_loss: 0.0894 - val_accuracy: 0.9725 - 11s/epoch - 129ms/step
# Epoch 6/30
# 88/88 - 11s - loss: 0.1252 - accuracy: 0.9843 - val_loss: 8.5445e-04 - val_accuracy: 1.0000 - 11s/epoch - 129ms/step
# Epoch 7/30
# 88/88 - 11s - loss: 0.1282 - accuracy: 0.9814 - val_loss: 1.4341 - val_accuracy: 0.8842 - 11s/epoch - 130ms/step
# Epoch 8/30
# 88/88 - 12s - loss: 0.0935 - accuracy: 0.9871 - val_loss: 0.0958 - val_accuracy: 0.9789 - 12s/epoch - 131ms/step
# Epoch 9/30
# 88/88 - 11s - loss: 0.0400 - accuracy: 0.9921 - val_loss: 0.1180 - val_accuracy: 0.9815 - 11s/epoch - 130ms/step
# Epoch 10/30
# 88/88 - 11s - loss: 0.1058 - accuracy: 0.9875 - val_loss: 0.0553 - val_accuracy: 0.9912 - 11s/epoch - 130ms/step
# Epoch 11/30
# 88/88 - 11s - loss: 0.0331 - accuracy: 0.9961 - val_loss: 0.0027 - val_accuracy: 0.9991 - 11s/epoch - 130ms/step
# Epoch 12/30
# 88/88 - 13s - loss: 0.2000 - accuracy: 0.9907 - val_loss: 0.0025 - val_accuracy: 0.9989 - 13s/epoch - 146ms/step
# Epoch 13/30
# 88/88 - 11s - loss: 0.1036 - accuracy: 0.9914 - val_loss: 0.5616 - val_accuracy: 0.9278 - 11s/epoch - 129ms/step
# Epoch 14/30
# 88/88 - 12s - loss: 0.0641 - accuracy: 0.9921 - val_loss: 0.0067 - val_accuracy: 0.9976 - 12s/epoch - 135ms/step
# Epoch 15/30
# 88/88 - 13s - loss: 0.0198 - accuracy: 0.9975 - val_loss: 0.0270 - val_accuracy: 0.9976 - 13s/epoch - 142ms/step
# Epoch 16/30
# 88/88 - 12s - loss: 0.0516 - accuracy: 0.9946 - val_loss: 8.7638e-04 - val_accuracy: 0.9998 - 12s/epoch - 141ms/step
# Epoch 17/30
# 88/88 - 12s - loss: 0.1180 - accuracy: 0.9932 - val_loss: 0.0409 - val_accuracy: 0.9923 - 12s/epoch - 141ms/step
# Epoch 18/30
# 88/88 - 12s - loss: 0.0250 - accuracy: 0.9964 - val_loss: 9.1973e-04 - val_accuracy: 0.9996 - 12s/epoch - 134ms/step
# Epoch 19/30
# 88/88 - 12s - loss: 0.0562 - accuracy: 0.9971 - val_loss: 0.0077 - val_accuracy: 0.9976 - 12s/epoch - 137ms/step
# Epoch 20/30
# 88/88 - 12s - loss: 1.6699e-04 - accuracy: 1.0000 - val_loss: 4.1268e-05 - val_accuracy: 1.0000 - 12s/epoch - 133ms/step
# Epoch 21/30
# 88/88 - 15s - loss: 0.4227 - accuracy: 0.9857 - val_loss: 0.0219 - val_accuracy: 0.9938 - 15s/epoch - 169ms/step
# Epoch 22/30
# 88/88 - 16s - loss: 0.0119 - accuracy: 0.9982 - val_loss: 0.0077 - val_accuracy: 0.9987 - 16s/epoch - 179ms/step
# Epoch 23/30
# 88/88 - 15s - loss: 0.0516 - accuracy: 0.9932 - val_loss: 0.3887 - val_accuracy: 0.9598 - 15s/epoch - 176ms/step
# Epoch 24/30
# 88/88 - 16s - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0103 - val_accuracy: 0.9974 - 16s/epoch - 184ms/step
# Epoch 25/30
# 88/88 - 15s - loss: 1.4433e-05 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9953 - 15s/epoch - 175ms/step
# Epoch 26/30
# 88/88 - 16s - loss: 0.0264 - accuracy: 0.9971 - val_loss: 0.0243 - val_accuracy: 0.9961 - 16s/epoch - 182ms/step
# Epoch 27/30
# 88/88 - 15s - loss: 0.1067 - accuracy: 0.9928 - val_loss: 0.0222 - val_accuracy: 0.9955 - 15s/epoch - 173ms/step
# Epoch 28/30
# 88/88 - 16s - loss: 2.1322e-06 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9955 - 16s/epoch - 179ms/step
# Epoch 29/30
# 88/88 - 19s - loss: 0.0473 - accuracy: 0.9957 - val_loss: 0.0016 - val_accuracy: 0.9998 - 19s/epoch - 220ms/step
# Epoch 30/30
# 88/88 - 17s - loss: 0.0247 - accuracy: 0.9982 - val_loss: 0.0093 - val_accuracy: 0.9974 - 17s/epoch - 199ms/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_, train_ims, test_ims = load_dataset_images()

train_ims = { category: [ image for collection in collections for image in collection ] for category, collections in train_ims.items() }
test_ims = { category: [ image for collection in collections for image in collection ] for category, collections in test_ims.items() }

ims = []
labels = []

for category, images in train_ims.items():
    ims.extend(images)
    labels.extend([category for _ in range(len(images))])

for category, images in test_ims.items():
    ims.extend(images)
    labels.extend([category for _ in range(len(images))])

ims = np.array([img_to_array(load_img(image)) for collection in train_dataset.values() for image in ims])

expected = model.predict(ims, verbose=2)
